# %%
#to create data set import make_classifiction
from sklearn.datasets import make_classification

# %%
#x independent feature
# y is dependent feature
x,y = make_classification(n_samples = 1000 , n_features = 2 , n_redundant = 0,n_clusters_per_class = 1 ,
                          weights = [0.90] , random_state = 1 )

# %%
import pandas as pd 
df1 = pd.DataFrame(x,columns=['f1','f2'])
df2 = pd.DataFrame(y,columns=['target'])
df = pd.concat([df1,df2],axis=1)

# %%
df.head()
# Out:
#          f1        f2  target
# 0  1.536830 -1.398694       1
# 1  1.551108  1.810329       0
# 2  1.293619  1.010946       0
# 3  1.119889  1.632518       0
# 4  1.042356  1.121529       0

# %%
df['target'].value_counts()
# Out:
# 0    894
# 1    106
# Name: target, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['f1'],df['f2'],c=df['target'])

# %%
from imblearn.over_sampling import SMOTE

# %%
##transform the dataset
oversample = SMOTE()
x,y = oversample.fit_resample(final_df[['f1','f2']],df['target'])

# %%
x.shape
# Out:
# (1788, 2)

# %%
y.shape
# Out:
# (1788,)

# %%
import pandas as pd 
df1 = pd.DataFrame(x,columns=['f1','f2'])
df2 = pd.DataFrame(y,columns=['target'])
df = pd.concat([df1,df2],axis=1)

# %%
plt.scatter(df['f1'],oversample_df['f2'],c=oversample_df['target'])
